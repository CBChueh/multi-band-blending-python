# %%
from PIL import Image
from IPython.display import display
# !cd '/Users/chuanborchueh/Documents/Coding/multi-band-blending-python/'
# !ls
# Out:
# LICENSE                multi_band_blending.py run.ipynb
# README.md              result.png             samples

# %%
# !python3 multi_band_blending.py -f 'samples/l.jpg' -s 'samples/r.jpg' -o 256 -H 
img = Image.open('result.png')
# Out:
# args:  {'first': 'samples/r.jpg', 'second': 'samples/l.jpg', 'mask': None, 'overlap': 256, 'leveln': None, 'half': True}
# blending result has been saved in 'result.png'

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>
