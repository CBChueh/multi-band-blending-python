# %%
from PIL import Image
from IPython.display import display

# %%
# !python3 multi_band_blending.py -f ../samples/l.jpg -s ../samples/r.jpg -o 256
img = Image.open('result.png')
display(img)
# Out:
# args:  {'first': '../samples/l.jpg', 'second': '../samples/r.jpg', 'mask': None, 'overlap': 256, 'leveln': None, 'half': False}
# blending result has been saved in 'result.png'
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=768x512>
